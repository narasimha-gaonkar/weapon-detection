# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Jul 10 18:05:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.5/627.5 kB 17.4 MB/s eta 0:00:00
# ...

# %%
#!yolo predict model=yolov8n.pt source='/content/Weapon1.png'

# %%
# %cd "/content/drive/MyDrive/Weapon Detection"
# Out:
# /content/drive/MyDrive/Weapon Detection

# %%
# !ls
# Out:
#  dog.jpeg   runs  'Test Run 1'	 yolov8n.pt   yolov8x.pt

# %%
#!yolo detect predict model=yolov8x.pt source=Data/test/images classes=['weapon']

# %%
# !ls
# Out:
#  dog.jpeg   runs  'Test Run 1'	 yolov8n.pt   yolov8x.pt

# %%
# %%javascript
#
# function ClickConnect(){
#     console.log("Working");
#     document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)

# %%
# !yolo detect train data=Data/data.yaml model=yolov8n.pt epochs=10 imgsz=640 plots=True

# %% [markdown]
# #Validation

# %%
# !ls

# %%
# !yolo detect val data=Data/data.yaml model=runs/detect/train/weights/best.pt
# Out:
# /bin/bash: yolo: command not found

# %%
# !ls

# %% [markdown]
# #Test

# %%
# !yolo detect predict data=Data/data.yaml model=runs/detect/train/weights/best.pt conf=0.5 source=Data/test/images
# Out:
# Ultralytics YOLOv8.0.130 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43608150 parameters, 0 gradients
#
# image 1/2 /content/drive/MyDrive/Weapon Detection/Data/test/images/Screenshot 2023-06-28 at 10.21.27 PM.png: 640x640 (no detections), 63.0ms
# image 2/2 /content/drive/MyDrive/Weapon Detection/Data/test/images/armas (34).jpg: 544x640 (no detections), 64.2ms
# Speed: 3.2ms preprocess, 63.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# Results saved to runs/detect/predict
