# %%
# !pip install pylabel

# %%
from pylabel import importer

# %%
dataset = importer.ImportVOC(path='Intitial Dataset/xmls')
# Out:
# Importing VOC files...: 100%|██████████| 5078/5078 [00:00<00:00, 6439.66it/s]

# %%
dataset.export.ExportToYoloV5()
# Out:
# Exporting YOLO files...: 100%|██████████| 5078/5078 [00:02<00:00, 1702.48it/s]
# ['training/dataset.yaml',
#  'training/labels/armas (2038).txt',
#  'training/labels/knife_1094.txt',
#  'training/labels/armas (2468).txt',
#  'training/labels/armas (945).txt',
#  'training/labels/DefenseKnifeAttack0059.txt',
#  'training/labels/armas (2192).txt',
#  'training/labels/armas (1614).txt',
#  'training/labels/armas (416).txt',
#  'training/labels/KravMagaKnifeDefenseTechniques768.txt',
#  'training/labels/armas (1244).txt',
#  'training/labels/knife_1080.txt',
#  'training/labels/armas (2891).txt',
#  'training/labels/armas (553).txt',
#  'training/labels/armas (1751).txt',
#  'training/labels/armas (103).txt',
#  'training/labels/armas (1301).txt',
#  'training/labels/KravMagaTraining20626.txt',
#  'training/labels/DSC_00121.txt',
#  'training/labels/armas (2487).txt',
#  'training/labels/DefenseKnifeAttack0071.txt',
#  'training/labels/armas (2).txt',
# ...
