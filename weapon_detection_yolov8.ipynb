# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.9/625.9 kB 3.7 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 22.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 MB 21.9 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 43.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 33.0 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...

# %%
# !ls
# Out:
# Data                          Pistol detection
# Data.zip                      main.py
# Data_1.zip                    test
# Knife_detection               weapon_detection_yolov8.ipynb
# Original Dataset

# %%
# !yolo detect train data=Data/data.yaml model=yolov8n.pt epochs=5 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.9 torch-2.0.1 CPU
# ...
